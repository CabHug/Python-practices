# %%
import pandas as pd

path = "online_retail.csv"

df = pd.read_csv(path)
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df.shape
# Out:
# (541909, 8)

# %%
# Retreive daily sales

d_sales = df['Quantity']
d_sales
# Out:
# 0          6
# 1          6
# 2          8
# 3          6
# 4          6
#           ..
# 541904    12
# 541905     6
# 541906     4
# 541907     4
# 541908     3
# Name: Quantity, Length: 541909, dtype: int64

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
print(d_sales.mean())
# Out:
# 9.55224954743324

# %%
d_sales.sum()
# Out:
# np.int64(5176450)

# %%
d_sales.count()
# Out:
# np.int64(541909)

# %% [markdown]
# # Seleccion de datos en Pandas, iloc y loc

# %%
# Busqueda con iloc, esta funcion me permite buscar filas y columnas por indice, es un metodo de el dataframe

fst_five_rows = df.iloc[0:5]
fst_five_rows
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# En pandas la convencion simpre sera [fila, columna]
# en este caso puedo seleccionar un numero especifico de filas y columnas
iloc_rows = df.iloc[0:5, 0:2]
iloc_rows
# Out:
#   InvoiceNo StockCode
# 0    536365    85123A
# 1    536365     71053
# 2    536365    84406B
# 3    536365    84029G
# 4    536365    84029E

# %%
# Tambien puedo utilizar la funcion del data frame loc para buscar pero en este caso por etiqueta de columna
# in this case you could notice that the select rows tale the total number of index marked
fst_5_rows = df.loc[0:5, ['InvoiceNo', 'StockCode']]
fst_5_rows
# Out:
#   InvoiceNo StockCode
# 0    536365    85123A
# 1    536365     71053
# 2    536365    84406B
# 3    536365    84029G
# 4    536365    84029E
# 5    536365     22752

# %% [markdown]
# # Manejo de datos faltantes

# %%
# La funcion isna() is not available pregunta si algun dato no exite en el dataframe o serie, 
# toma como nulo los valores de None, np.nan, Nat(dato faltante de tiempo)

missing_d_sales = d_sales.isna()
missing_d_sales
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 541904    False
# 541905    False
# 541906    False
# 541907    False
# 541908    False
# Name: Quantity, Length: 541909, dtype: bool

# %%
missing_d_sales.sum()
# Out:
# np.int64(0)

# %%
missing_d_df = df.isna()
missing_d_df
# Out:
#         InvoiceNo  StockCode  Description  Quantity  InvoiceDate  UnitPrice  \
# 0           False      False        False     False        False      False
# 1           False      False        False     False        False      False
# 2           False      False        False     False        False      False
# 3           False      False        False     False        False      False
# 4           False      False        False     False        False      False
# ...           ...        ...          ...       ...          ...        ...
# 541904      False      False        False     False        False      False
# 541905      False      False        False     False        False      False
# 541906      False      False        False     False        False      False
# 541907      False      False        False     False        False      False
# 541908      False      False        False     False        False      False
#
#         CustomerID  Country
# ...

# %%
# La funcion sum me ayuda a encontrar cuantos datos faltantes tengo en total
missing_d_df.sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# eliminar filas del dataframe, puedo utilizar la funcion dropna, esta por defecto eliminal las filas de un Df especifico

no_mnissing_values = df.dropna()
no_mnissing_values
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# En esta seccion confirmo que los datos faltantes en las filas fueron eliminados
no_mnissing_values.isna().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
# Adicionalmente dropna() me permite eliminar columnas haciendo uso de su parametro axis
# df.dropna(axis=1) -> los valores que puesde tomar son 0 -> indica fila y 1 -> indica columna

missing_data = df
missing_data.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# al consultar de nuevo si hay algun dato como nulo o nota available podemos ver como se ha eliminado las columnas completas
missing_data.dropna(axis=1).isna().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# Country        0
# dtype: int64

# %%
# puedo hacer uso de la funcion fillna() el cuento toma un valor numerico, str o tambien una lista para llenar los laroles nulos en 

miss_dta = df
miss_dta.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# En este ejemplo puedo ver como la funcion fillna lleno la informacion faltante en el df
miss_dta.fillna(0).isna().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
# puedo tambien llenar columnas especificas

# first of all take the required colum

colum = df['Description']
colum
# Out:
# 0          WHITE HANGING HEART T-LIGHT HOLDER
# 1                         WHITE METAL LANTERN
# 2              CREAM CUPID HEARTS COAT HANGER
# 3         KNITTED UNION FLAG HOT WATER BOTTLE
# 4              RED WOOLLY HOTTIE WHITE HEART.
#                          ...
# 541904            PACK OF 20 SPACEBOY NAPKINS
# 541905           CHILDREN'S APRON DOLLY GIRL
# 541906          CHILDRENS CUTLERY DOLLY GIRL
# 541907        CHILDRENS CUTLERY CIRCUS PARADE
# 541908          BAKING SET 9 PIECE RETROSPOT
# Name: Description, Length: 541909, dtype: object

# %%
# I check if the selected colum has missing info haciendo uso de isna() junto a sum()
colum.isna().sum()
# Out:
# np.int64(1454)

# %%
# Hago uso de fillna() para llenar los campos faltantes con el valor de null, pero arreglo en el df general
# Para poder modificar el df directaemnte es importante agregar el parametro inplace=True el cual indica el cambio en los valores donde no hay datos
df['Description'].fillna('null', inplace=True)

# %%
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description         0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# ahora eliminare las filas donde el customer id no esta disponible
#df.dropna(inplace=True)
# tambien puedo utlizar el parametro subset = [colum1, colum2] donde paso una lista de columnas a revisar
df.dropna(subset = ['CustomerID'], inplace = True)

# %%
df.isna().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %% [markdown]
# # Transformaciones y manipulacion de datos con pandas

# %%
# para la creacion de una nueva columna puedo utiulizar la notacion df['nombre_nueva_columna']

import pandas as pd

path = "online_retail.csv"

df = pd.read_csv(path)
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df['Precio total'] = df['Quantity'] * df['UnitPrice']

# %%
# en esta parte se puede ver como se ha agregado al final la nueva columna requerida
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
# Para optener informacion relacionada con los datos tipo de dato nombre de columnas puedo utilizar la funcion .info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   InvoiceNo     541909 non-null  object
#  1   StockCode     541909 non-null  object
#  2   Description   540455 non-null  object
#  3   Quantity      541909 non-null  int64
#  4   InvoiceDate   541909 non-null  object
#  5   UnitPrice     541909 non-null  float64
#  6   CustomerID    406829 non-null  float64
#  7   Country       541909 non-null  object
#  8   Precio total  541909 non-null  float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 37.2+ MB

# %%
# De lo anterior se puede ver que la columna InvoiceDate tiene un tipo de dato incorrecto
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB
# None

# %%
# tambien puedo aplicar una funcion lambda a cada item de una columna especifica usando la funcion apply()

df['Precio con descuento'] = df['UnitPrice'].apply(lambda x: x*0.9)
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
# Con la funcion apply tambien puedo aplicar una fucnion a filas con valores numericos u categoricosabs

# en este ejemplo voy a aplicar una funcion para categorizar una variable cuantitativaabs
def categizarPrecio(precio):
    if precio > 0 and precio <= 10:
        return 'Bajo'
    elif precio > 10 and precio <= 25:
        return 'Medio'
    else:
        return 'Alto'


df['Categoria precio'] = df['UnitPrice'].apply(categizarPrecio)
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %% [markdown]
# # Analisis de ventas con pandas: agrupaciones y estadistica

# %%
# para la creacion de una nueva columna puedo utiulizar la notacion df['nombre_nueva_columna']

import pandas as pd

path = "online_retail.csv"

df = pd.read_csv(path)
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
country_count = df['Country'].value_counts()
country_count
# Out:
# Country
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %%
# unso de la funcion groupby()
# lo que hacer este codigo es hacer un agrupamiento de los diferentes paises en country y luego tomar la columna de quatity y sumar
#donde haya una coincidencia
ctry_group = df.groupby('Country')['UnitPrice'].sum()
ctry_group
# Out:
# Country
# Australia                  4054.750
# Austria                    1701.520
# Bahrain                      86.570
# Belgium                    7540.130
# Brazil                      142.600
# Canada                      910.580
# Channel Islands            3738.550
# Cyprus                     3920.070
# Czech Republic               88.150
# Denmark                    1266.950
# EIRE                      48447.190
# European Community          294.050
# Finland                    3786.850
# France                    43031.990
# Germany                   37666.000
# Greece                      713.290
# Hong Kong                 12241.500
# Iceland                     481.210
# Israel                     1079.040
# Italy                      3879.390
# Japan                       814.860
# Lebanon                     242.440
# Lithuania                    99.440
# Malta                       666.010
# Netherlands                6492.550
# Norway                     6529.060
# ...

# %%
# lo que se hace en este codigo es con groupby() se agrupa todo por los valores de country y luego se toma la columna
# [UnitPrice]a la cual le agregamos con agg() dos fucnones mas como mean y sum

countr_stats = df.groupby('Country')['UnitPrice'].agg(['mean','sum'])
countr_stats
# Out:
#                             mean          sum
# Country
# Australia               3.220612     4054.750
# Austria                 4.243192     1701.520
# Bahrain                 4.556316       86.570
# Belgium                 3.644335     7540.130
# Brazil                  4.456250      142.600
# Canada                  6.030331      910.580
# Channel Islands         4.932124     3738.550
# Cyprus                  6.302363     3920.070
# Czech Republic          2.938333       88.150
# Denmark                 3.256941     1266.950
# EIRE                    5.911077    48447.190
# European Community      4.820492      294.050
# Finland                 5.448705     3786.850
# France                  5.028864    43031.990
# Germany                 3.966930    37666.000
# Greece                  4.885548      713.290
# Hong Kong              42.505208    12241.500
# Iceland                 2.644011      481.210
# Israel                  3.633131     1079.040
# ...

# %%
country_stock = df.groupby(['Country', 'StockCode'])['UnitPrice'].agg(['sum'])
country_stock
# Out:
#                         sum
# Country     StockCode
# Australia   15036      0.72
#             15056BL    5.95
#             16161P     0.34
#             16169E     0.42
#             20665      2.95
# ...                     ...
# Unspecified 85180A     4.65
#             85180B     4.65
#             85212      0.29
#             85213      0.29
#             85227      2.55
#
# [19839 rows x 1 columns]

# %%
country_stock2 = df.groupby(['Country', 'StockCode'])[['UnitPrice', 'Quantity']].agg(['sum'])
country_stock2
# Out:
#                       UnitPrice Quantity
#                             sum      sum
# Country     StockCode
# Australia   15036          0.72      600
#             15056BL        5.95        3
#             16161P         0.34      400
#             16169E         0.42       25
#             20665          2.95        6
# ...                         ...      ...
# Unspecified 85180A         4.65        2
#             85180B         4.65        1
#             85212          0.29       12
#             85213          0.29       12
#             85227          2.55       10
#
# [19839 rows x 2 columns]

# %%
# Tambien puedo aplicar funciones a grupaciones 

def total_revenue(group):
    return (group['Quantity'] * group['UnitPrice']).sum()


rev_per_country = df.groupby(['Country']).apply(total_revenue)
print(rev_per_country)
# Out:
# Country
# Australia                137077.270
# Austria                   10154.320
# Bahrain                     548.400
# Belgium                   40910.960
# Brazil                     1143.600
# Canada                     3666.380
# Channel Islands           20086.290
# Cyprus                    12946.290
# Czech Republic              707.720
# Denmark                   18768.140
# EIRE                     263276.820
# European Community         1291.750
# Finland                   22326.740
# France                   197403.900
# Germany                  221698.210
# Greece                     4710.520
# Hong Kong                 10117.040
# Iceland                    4310.000
# Israel                     7907.820
# Italy                     16890.510
# Japan                     35340.620
# Lebanon                    1693.880
# Lithuania                  1661.060
# Malta                      2505.470
# Netherlands              284661.540
# Norway                    35163.460
# ...
